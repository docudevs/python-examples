# %% [markdown]
# # DocuDevs: Extract Structured Data from Documents
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/docudevs/python-examples/blob/main/01-basic-extraction.ipynb)
# [![GitHub](https://img.shields.io/badge/GitHub-View_Source-blue?logo=github)](https://github.com/docudevs/python-examples)
#
# Extract invoices, receipts, and any document into typed Python objects using prompts and Pydantic schemas.
#
# **What you'll learn:**
# - Prompt-based extraction (quick and easy)
# - Type-safe extraction with Pydantic models
# - Barcode and QR code scanning

# %%
# Install dependencies (required in Colab)
# %pip install -q docu-devs-api-client pydantic

# %%
import os
import json
from docudevs import DocuDevsClient

# Set your API key:
# Option 1: Colab Secrets (recommended) — add DOCUDEVS_API_KEY in the 🔑 sidebar
# Option 2: Environment variable
# Option 3: Set directly below
try:
    from google.colab import userdata
    API_KEY = userdata.get("DOCUDEVS_API_KEY")
except Exception:
    API_KEY = os.getenv("DOCUDEVS_API_KEY", "your-api-key-here")

if not API_KEY or API_KEY == "your-api-key-here":
    raise ValueError("Set your DOCUDEVS_API_KEY — get one at https://docudevs.ai")

client = DocuDevsClient(token=API_KEY)
print("✓ Connected to DocuDevs API")

# %% [markdown]
# ## Simple Prompt-Based Extraction
#
# The easiest way to extract data is to just describe what you want in plain English.
# Let's extract some basic info from an invoice.

# %%
# Download sample documents (Colab doesn't have local files)
import urllib.request
from pathlib import Path

Path("docs").mkdir(exist_ok=True)
for name in ["invoice.pdf"]:
    if not Path(f"docs/{name}").exists():
        urllib.request.urlretrieve(
            f"https://raw.githubusercontent.com/docudevs/python-examples/main/docs/{name}",
            f"docs/{name}"
        )
        print(f"Downloaded {name}")

with open("docs/invoice.pdf", "rb") as f:
    invoice_bytes = f.read()

print(f"Loaded invoice: {len(invoice_bytes)} bytes")

# %%
# Submit the document with a simple prompt
job_id = await client.submit_and_process_document(
    document=invoice_bytes,
    document_mime_type="application/pdf",
    prompt="Extract the invoice number, date, total amount, and vendor name. Return null for any field that is not present in the document."
)

print(f"Job submitted: {job_id}")

# %%
# Wait for the result
result = await client.wait_until_ready(job_id, result_format="json", poll_interval=5, timeout=300)
print(json.dumps(result, indent=2))

# %% [markdown]
# ## Type-Safe Extraction with Pydantic
#
# For production use, you want **consistent, validated data**. Pydantic models let you:
# - Define exactly what fields you need
# - Specify data types (numbers are numbers, not strings)
# - Add validation rules
# - Get autocomplete in your IDE
#
# Let's define a proper invoice schema. If a field might be missing from the source document, make it optional with a default of `None`. Required fields are useful for data that must exist, but they can make validation fail when the document genuinely lacks that value. They can also pressure the LLM to infer or invent a value instead of leaving it blank.

# %%
from pydantic import BaseModel, Field
from typing import Optional
from docudevs import json_schema


class LineItem(BaseModel):
    """A single line item on the invoice."""
    description: str = Field(description="Description of the item or service")
    quantity: int = Field(default=1, description="Quantity ordered")
    unit_price: float = Field(description="Price per unit")
    total: float = Field(description="Line total (quantity * unit_price)")


class Invoice(BaseModel):
    """Extracted invoice data."""
    invoice_number: Optional[str] = Field(default=None, description="Unique invoice identifier, if present")
    date: str = Field(description="Invoice date in YYYY-MM-DD format")
    vendor_name: str = Field(description="Name of the vendor/seller")
    vendor_address: Optional[str] = Field(default=None, description="Vendor's address")
    line_items: list[LineItem] = Field(default_factory=list, description="List of items")
    subtotal: Optional[float] = Field(default=None, description="Subtotal before tax")
    tax: Optional[float] = Field(default=None, description="Tax amount")
    total: float = Field(description="Total amount due")


# Generate the JSON schema from the Pydantic model
schema_json = json_schema(Invoice)
print("Generated schema:")
print(json.dumps(json.loads(schema_json), indent=2))

# %%
# Process the document with our schema
job_id = await client.submit_and_process_document(
    document=invoice_bytes,
    document_mime_type="application/pdf",
    schema=schema_json,
    prompt="Extract all invoice details according to the schema. Use null for optional fields that are not present; do not infer or invent missing values."
)

print(f"Job submitted: {job_id}")

# %%
# Get the result and parse it back into our Pydantic model
result = await client.wait_until_ready(job_id, result_format="json", poll_interval=5, timeout=300)

# Validate and parse with Pydantic
invoice = Invoice.model_validate(result)

print(f"Invoice #: {invoice.invoice_number or 'not found'}")
print(f"Date: {invoice.date}")
print(f"Vendor: {invoice.vendor_name}")
print(f"Total: ${invoice.total:.2f}")
print(f"\nLine items ({len(invoice.line_items)}):")
for item in invoice.line_items:
    print(f"  - {item.description}: {item.quantity} x ${item.unit_price:.2f} = ${item.total:.2f}")

# %% [markdown]
# ## Extracting Barcodes and QR Codes
#
# Many documents contain barcodes or QR codes. DocuDevs can extract these too - just enable the `barcodes` option.

# %%
# This example is disabled by default so Run All does not start a third job.
# Set to True when you want to try barcode/QR extraction.
RUN_BARCODE_EXAMPLE = False

if RUN_BARCODE_EXAMPLE:
    try:
        with open("docs/invoice.pdf", "rb") as f:
            qr_doc = f.read()

        job_id = await client.submit_and_process_document(
            document=qr_doc,
            document_mime_type="application/pdf",
            prompt="Extract all information including any QR code data. Return null for fields that are not present.",
            barcodes=True,
        )

        result = await client.wait_until_ready(job_id, result_format="json", poll_interval=5, timeout=300)
        print(json.dumps(result, indent=2))
    except FileNotFoundError:
        print("QR-bill sample not found. Try with your own document!")
else:
    print("Set RUN_BARCODE_EXAMPLE = True to run the barcode/QR example")

# %% [markdown]
# ## Tips for Better Extraction
#
# 1. **Be specific in your prompts**: Instead of "extract data", say "extract the invoice number, date, and line items"
#
# 2. **Tell the model how to handle missing data**: If a value may not exist, make the schema field optional and ask the model to return `null` instead of guessing
#
# 3. **Use Pydantic models**: They enforce structure and make your code more maintainable
#
# 4. **Add field descriptions**: The AI uses these to understand what you want
#
# 5. **Start simple**: Get basic extraction working, then add complexity
#
# 6. **Test with representative documents**: Use real samples that represent your actual workload

# %% [markdown]
# ## Next Steps
#
# - **[Map-Reduce Extraction](02-map-reduce.ipynb)**: Handle very long documents (50+ pages)
# - **[Knowledge Search](03-knowledge-search.ipynb)**: Enrich extractions with your own knowledge base
# - **[Operations](04-operations.ipynb)**: Error analysis and follow-up questions on documents
